# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashita78/englishclasses/blob/main/Clase_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***¿Cómo estas hoy?*** ⁉ ✋

# %% [markdown]
# # 1. Introducción a Pandas

# %%
import pandas as pd
print("Pandas version:", pd.__version__)
# Out:
# Pandas version: 2.0.3

# %%
import numpy as np

# %% [markdown]
# # 2. Estructuras de Datos en Pandas

# %% [markdown]
# **Series:**
#
# Una Serie en Pandas es una estructura de datos unidimensional que puede contener cualquier tipo de datos (enteros, cadenas, números de punto flotante, objetos de Python, etc.). Cada elemento de una Serie está asociado con un índice, que es una etiqueta que identifica cada elemento de la Serie.
# * Homogéneas: Todos los elementos de una Serie deben ser del mismo tipo de datos.
# * Etiquetadas: Cada elemento está indexado por una etiqueta única.

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
print(s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# **Dataframe:**
#
# Un DataFrame es una estructura de datos bidimensional en Pandas, similar a una tabla de datos relacional, donde cada columna puede tener un tipo diferente (numérico, string, boolean, etc.). Es fundamentalmente una colección de Series que comparten el mismo índice.
#
# Características de los DataFrames:
#
# * Heterogéneas: Puede contener columnas de diferentes tipos de datos.
# * Mutables: Tamaño y contenido mutables (puede modificar columnas y filas después de la creación).
# * Etiquetados: Las filas y columnas tienen etiquetas.

# %%
data = {'Nombres': ['Ana', 'Luis', 'Carmen'],
        'Edad': [28, 34, 29],
        'Ciudad': ['Madrid', 'Barcelona', 'Valencia']}
df = pd.DataFrame(data)
print(df)
# Out:
#   Nombres  Edad     Ciudad
# 0     Ana    28     Madrid
# 1    Luis    34  Barcelona
# 2  Carmen    29   Valencia

# %%
type(data)
# Out:
# dict

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ***Hagamos nuestro propio dataset de la 4ta generación del bootcamp en DS*** ⁉ ✋

# %% [markdown]
# Ingresa a : https://docs.google.com/spreadsheets/d/1z49gtXBqVfqMP5SJoQB802M-G1BfR63uY71A_t7z6vk/edit?usp=sharing e inserta tus datos

# %% [markdown]
# # 3. Carga y Guardado de Datos

# %%
df = pd.read_csv('/content/Data, clase de pandas - Hoja 1.csv')
#df.to_excel('datos_guardados.xlsx', index=False)
df
# Out:
#              A     Edad              Ciudad  formato_name formato_edad  \
# 0         Joel       40                CDMX           NaN          NaN
# 1      Marcela       53  Comodoro Rivadavia      Marcela'          53'
# 2       Andrea       26                CDMX     'Andrea',        '26',
# 3    Monserrat       33         Guadalajara  'Monserrat',        '33',
# 4         José       27            Trujillo       'José',        '27',
# ..         ...      ...                 ...           ...          ...
# 107      Jose   35 años                CDMX      'Jose ',   '35 años',
# 108        NaN      NaN                 NaN           NaN          NaN
# 109       Alex       21           Monterrey       'Alex',        '21',
# 110   Eleonora       22              Berlin   'Eleonora',        '22',
# 111    Micaela       23            Santa Fe           NaN          NaN
#
#      formato_ciudad
# 0               NaN
# 1               CR'
# 2           'CDMX',
# 3    'Guadalajara',
# 4       'Trujillo',
# ..              ...
# 107         'CDMX',
# 108             NaN
# 109    'Monterrey',
# 110       'Berlin',
# 111             NaN
#
# [112 rows x 6 columns]

# %% [markdown]
# # 4. Inspección y Limpieza de Datos

# %% [markdown]
# **Inspección:**
#
# La inspección de datos te ayuda a entender mejor la estructura y el contenido de tu DataFrame o Serie.

# %%
print(df.head(3))
# Out:
#          A Edad              Ciudad formato_name formato_edad formato_ciudad
# 0     Joel   40                CDMX          NaN          NaN            NaN
# 1  Marcela   53  Comodoro Rivadavia     Marcela'          53'            CR'
# 2   Andrea   26                CDMX    'Andrea',        '26',        'CDMX',

# %%
df.tail(3)  # Muestra las últimas 'n' filas del DataFrame
# Out:
#             A Edad     Ciudad formato_name formato_edad formato_ciudad
# 109      Alex   21  Monterrey      'Alex',        '21',   'Monterrey',
# 110  Eleonora   22     Berlin  'Eleonora',        '22',      'Berlin',
# 111   Micaela   23   Santa Fe          NaN          NaN            NaN

# %%
df.shape  # Retorna una tupla con el número de filas y columnas
# Out:
# (112, 6)

# %%
df.dtypes  # Retorna los tipos de datos de cada columna
# Out:
# A                 object
# Edad              object
# Ciudad            object
# formato_name      object
# formato_edad      object
# formato_ciudad    object
# dtype: object

# %%
df.describe()  # Proporciona un resumen estadístico de las columnas numéricas
# Out:
#              A Edad Ciudad formato_name formato_edad formato_ciudad
# count       94   94     94           91           91             91
# unique      81   35     57           78           35             55
# top     sergio   26   CDMX    'sergio',        '26',        'CDMX',
# freq         5   12     17            5           12             16

# %%
df.count()  # Cuenta el número de valores no nulos en cada columna
# Out:
# A                 94
# Edad              94
# Ciudad            94
# formato_name      91
# formato_edad      91
# formato_ciudad    91
# dtype: int64

# %%
df.info()  # Proporciona un resumen conciso del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   A               94 non-null     object
#  1   Edad            94 non-null     object
#  2   Ciudad          94 non-null     object
#  3   formato_name    91 non-null     object
#  4   formato_edad    91 non-null     object
#  5   formato_ciudad  91 non-null     object
# dtypes: object(6)
# memory usage: 5.4+ KB

# %%
df['A'].unique()
# Out:
# array(['Joel', 'Marcela', 'Andrea', 'Monserrat', 'José', 'Sam', 'Anita',
#        'Erick', 'Karen', 'Paola', 'Lucia', 'Giovanna', 'Valentina',
#        'Maynez', 'Carol', 'Tomas', 'sergio', 'Jorge', 'Armando',
#        'Cynthia', 'Marisa', 'Luis', 'Dana', 'Cristian', 'Cesar', 'Odre',
#        'Christian', 'Iván', 'Gio', 'Gaston', 'fernando', 'Miguel',
#        'Duvan', 'Arturo', 'Jhonner', 'Cosme Fulanito', 'Alejandro Villa',
#        'Axel', 'Flavia', 'Chapo Guzman', 'josafat', 'Ivan', 'Alejandro',
#        'Saul', 'Goku', 'Jose', 'COsme ', 'Gibran', 'Sergio', 'Marco',
#        'Jorge González', 'Juan Manuel', 'Picolo', 'Emilio Alejandro',
#        'Flavio', 'Arturo ', 'Alfredo', 'Chris', 'Fernanda', 'Federico',
#        'Mateo', 'Alexis', 'Otoniel', nan, 'Andres', 'Edgar', 'EVANGELINA',
#        'Abril Gonzalez', 'Camilo Osorio', 'Juan Machado',
#        'Fernando Arellano', 'armando', 'Cody', 'Paquita Cabeza',
#        'Pancho Lopez', 'Benito', 'Naomi', 'Sofia', 'Jose ', 'Alex',
#        'Eleonora', 'Micaela'], dtype=object)

# %%
df['Edad'].unique()  # Muestra los valores únicos en la columna especificada
# Out:
# array(['40', '53', '26', '33', '27', '35', '25', '29', '47', '24', '30',
#        '21', '45', '36', '28', '52', '34', '44', '39', '38', '23', '68',
#        '145', '32', '50', '31', '500', '22', '1000', '57', 'Munoz', nan,
#        '48', '20', '15', '35 años'], dtype=object)

# %% [markdown]
# **Limpieza:**
#
# La limpieza de datos implica modificar o remover datos incorrectos, incompletos, irrelevantes, duplicados o mal formateados de un dataset.

# %%
df.dropna()  # Elimina filas con valores NaN
#df2 = df.dropna(axis=1)  # Elimina columnas con valores NaN
#df2
# Out:
#              A     Edad              Ciudad  formato_name formato_edad  \
# 1      Marcela       53  Comodoro Rivadavia      Marcela'          53'
# 2       Andrea       26                CDMX     'Andrea',        '26',
# 3    Monserrat       33         Guadalajara  'Monserrat',        '33',
# 4         José       27            Trujillo       'José',        '27',
# 5          Sam       35             Atlanta        'Sam',        '35',
# ..         ...      ...                 ...           ...          ...
# 104      Naomi       25                CDMX      'Naomi',        '25',
# 106      Sofia       35               Salta      'Sofia',        '35',
# 107      Jose   35 años                CDMX      'Jose ',   '35 años',
# 109       Alex       21           Monterrey       'Alex',        '21',
# 110   Eleonora       22              Berlin   'Eleonora',        '22',
#
#      formato_ciudad
# 1               CR'
# 2           'CDMX',
# 3    'Guadalajara',
# 4       'Trujillo',
# 5        'Atlanta',
# ..              ...
# 104         'CDMX',
# 106        'Salta',
# 107         'CDMX',
# 109    'Monterrey',
# 110       'Berlin',
#
# [91 rows x 6 columns]

# %%
df.drop_duplicates(inplace=True)  # Elimina filas duplicadas

# %%
len(df)
# Out:
# 88

# %%
value = 'si'
df.fillna(value)  # Rellena los valores NaN con el 'value' especificado
# Out:
#              A     Edad              Ciudad  formato_name formato_edad  \
# 0         Joel       40                CDMX            si           si
# 1      Marcela       53  Comodoro Rivadavia      Marcela'          53'
# 2       Andrea       26                CDMX     'Andrea',        '26',
# 3    Monserrat       33         Guadalajara  'Monserrat',        '33',
# 4         José       27            Trujillo       'José',        '27',
# ..         ...      ...                 ...           ...          ...
# 106      Sofia       35               Salta      'Sofia',        '35',
# 107      Jose   35 años                CDMX      'Jose ',   '35 años',
# 109       Alex       21           Monterrey       'Alex',        '21',
# 110   Eleonora       22              Berlin   'Eleonora',        '22',
# 111    Micaela       23            Santa Fe            si           si
#
#      formato_ciudad
# 0                si
# 1               CR'
# 2           'CDMX',
# 3    'Guadalajara',
# 4       'Trujillo',
# ..              ...
# 106        'Salta',
# 107         'CDMX',
# 109    'Monterrey',
# 110       'Berlin',
# 111              si
#
# [88 rows x 6 columns]

# %%
df.rename(columns={'A': 'Nombre'}, inplace=True)  # Renombra las columnas especificadas

# %%
df['Edad']= pd.to_numeric(df['Edad'], errors= 'coerce')

# %%
df2 = df.copy()

# %%
df2
# Out:
#         Nombre  Edad              Ciudad  formato_name formato_edad  \
# 0         Joel  40.0                CDMX           NaN          NaN
# 1      Marcela  53.0  Comodoro Rivadavia      Marcela'          53'
# 2       Andrea  26.0                CDMX     'Andrea',        '26',
# 3    Monserrat  33.0         Guadalajara  'Monserrat',        '33',
# 4         José  27.0            Trujillo       'José',        '27',
# ..         ...   ...                 ...           ...          ...
# 106      Sofia  35.0               Salta      'Sofia',        '35',
# 107      Jose    NaN                CDMX      'Jose ',   '35 años',
# 109       Alex  21.0           Monterrey       'Alex',        '21',
# 110   Eleonora  22.0              Berlin   'Eleonora',        '22',
# 111    Micaela  23.0            Santa Fe           NaN          NaN
#
#      formato_ciudad
# 0               NaN
# 1               CR'
# 2           'CDMX',
# 3    'Guadalajara',
# 4       'Trujillo',
# ..              ...
# 106        'Salta',
# 107         'CDMX',
# 109    'Monterrey',
# 110       'Berlin',
# 111             NaN
#
# [88 rows x 6 columns]

# %%
mediana = df2['Edad'].median()
mediana
# Out:
# 29.0

# %%
df2['Edad'].fillna(mediana, inplace = True)

# %%
df2
# Out:
#         Nombre  Edad              Ciudad  formato_name formato_edad  \
# 0         Joel  40.0                CDMX           NaN          NaN
# 1      Marcela  53.0  Comodoro Rivadavia      Marcela'          53'
# 2       Andrea  26.0                CDMX     'Andrea',        '26',
# 3    Monserrat  33.0         Guadalajara  'Monserrat',        '33',
# 4         José  27.0            Trujillo       'José',        '27',
# ..         ...   ...                 ...           ...          ...
# 106      Sofia  35.0               Salta      'Sofia',        '35',
# 107      Jose   29.0                CDMX      'Jose ',   '35 años',
# 109       Alex  21.0           Monterrey       'Alex',        '21',
# 110   Eleonora  22.0              Berlin   'Eleonora',        '22',
# 111    Micaela  23.0            Santa Fe           NaN          NaN
#
#      formato_ciudad
# 0               NaN
# 1               CR'
# 2           'CDMX',
# 3    'Guadalajara',
# 4       'Trujillo',
# ..              ...
# 106        'Salta',
# 107         'CDMX',
# 109    'Monterrey',
# 110       'Berlin',
# 111             NaN
#
# [88 rows x 6 columns]

# %%
#df['Edad'] = df['Edad'].astype(int)  # Cambia el tipo de datos de la columna a 'type'
df['Edad']= pd.to_numeric(df['Edad'], errors= 'coerce')
df.dropna()
# Out:
#         Nombre  Edad              Ciudad  formato_name formato_edad  \
# 1      Marcela  53.0  Comodoro Rivadavia      Marcela'          53'
# 2       Andrea  26.0                CDMX     'Andrea',        '26',
# 3    Monserrat  33.0         Guadalajara  'Monserrat',        '33',
# 4         José  27.0            Trujillo       'José',        '27',
# 5          Sam  35.0             Atlanta        'Sam',        '35',
# ..         ...   ...                 ...           ...          ...
# 99      Benito  36.0              Bogota     'Benito',        '36',
# 104      Naomi  25.0                CDMX      'Naomi',        '25',
# 106      Sofia  35.0               Salta      'Sofia',        '35',
# 109       Alex  21.0           Monterrey       'Alex',        '21',
# 110   Eleonora  22.0              Berlin   'Eleonora',        '22',
#
#      formato_ciudad
# 1               CR'
# 2           'CDMX',
# 3    'Guadalajara',
# 4       'Trujillo',
# 5        'Atlanta',
# ..              ...
# 99        'Bogota',
# 104         'CDMX',
# 106        'Salta',
# 109    'Monterrey',
# 110       'Berlin',
#
# [82 rows x 6 columns]

# %%
df.dropna(subset=['Edad'],inplace=True)

# %%
df['Edad'] = df['Edad'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, 0 to 111
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nombre          85 non-null     object
#  1   Edad            85 non-null     int64
#  2   Ciudad          85 non-null     object
#  3   formato_name    82 non-null     object
#  4   formato_edad    82 non-null     object
#  5   formato_ciudad  82 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 4.6+ KB

# %%
df
# Out:
#         Nombre  Edad              Ciudad  formato_name formato_edad  \
# 0         Joel    40                CDMX           NaN          NaN
# 1      Marcela    53  Comodoro Rivadavia      Marcela'          53'
# 2       Andrea    26                CDMX     'Andrea',        '26',
# 3    Monserrat    33         Guadalajara  'Monserrat',        '33',
# 4         José    27            Trujillo       'José',        '27',
# ..         ...   ...                 ...           ...          ...
# 104      Naomi    25                CDMX      'Naomi',        '25',
# 106      Sofia    35               Salta      'Sofia',        '35',
# 109       Alex    21           Monterrey       'Alex',        '21',
# 110   Eleonora    22              Berlin   'Eleonora',        '22',
# 111    Micaela    23            Santa Fe           NaN          NaN
#
#      formato_ciudad
# 0               NaN
# 1               CR'
# 2           'CDMX',
# 3    'Guadalajara',
# 4       'Trujillo',
# ..              ...
# 104         'CDMX',
# 106        'Salta',
# 109    'Monterrey',
# 110       'Berlin',
# 111             NaN
#
# [85 rows x 6 columns]

# %%
df['columna'].replace(to_replace, value, inplace=True)  # Reemplaza 'to_replace' por 'value' en la columna especificada

# %% [markdown]
# # 5. Manipulación de Datos

# %% [markdown]
# Selección y filtrado:

# %%
print(df['Nombre'])  # Selección de una columna
# Out:
# 0           Joel
# 1        Marcela
# 2         Andrea
# 3      Monserrat
# 4           José
#          ...
# 106        Sofia
# 107        Jose
# 109         Alex
# 110     Eleonora
# 111      Micaela
# Name: Nombre, Length: 88, dtype: object

# %%
print(df[df['Edad'] == 29])  # Filtrado por condición
# Out:
#     Nombre  Edad       Ciudad formato_name formato_edad  formato_ciudad
# 7    Erick  29.0  Guadalajara     'Erick',        '29',  'Guadalajara',
# 8    Karen  29.0   Cuernavaca     'Karen',        '29',   'Cuernavaca',
# 35  Arturo  29.0      Yucatan    'Arturo',        '29',      'Yucatan',

# %%
df2[['Ciudad', 'Edad']]  # Retorna un DataFrame con las columnas especificadas
# Out:
#                  Ciudad  Edad
# 0                  CDMX  40.0
# 1    Comodoro Rivadavia  53.0
# 2                  CDMX  26.0
# 3           Guadalajara  33.0
# 4              Trujillo  27.0
# ..                  ...   ...
# 106               Salta  35.0
# 107                CDMX  29.0
# 109           Monterrey  21.0
# 110              Berlin  22.0
# 111            Santa Fe  23.0
#
# [88 rows x 2 columns]

# %%
valor1 = 20
valor2 = 30
#df[df['Edad'] > valor]  # Retorna filas donde la columna es mayor que 'valor'
df[(df['Edad'] > valor1) & (df['Edad'] < valor2)]  # Condiciones múltiples
# Out:
#                 Nombre  Edad             Ciudad          formato_name  \
# 2               Andrea  26.0               CDMX             'Andrea',
# 4                 José  27.0           Trujillo               'José',
# 6                Anita  25.0        Guadalajara              'Anita',
# 7                Erick  29.0        Guadalajara              'Erick',
# 8                Karen  29.0         Cuernavaca              'Karen',
# 10               Lucia  24.0                 24              'Lucia',
# 12           Valentina  21.0           La Plata          'Valentina',
# 13              Maynez  27.0            Tijuana             'Maynez',
# 14               Carol  25.0               CDMX              'Carol',
# 15               Tomas  25.0       Buenos Aires              'Tomas',
# 16              sergio  26.0         Los patios             'sergio',
# 18             Armando  26.0               CDMX            'Armando',
# 20               Erick  28.0               CDMX              'Erick',
# 23                Dana  27.0            Córdoba               'Dana',
# 32              Miguel  23.0          Monterrey             'Miguel',
# 34               Duvan  26.0             Cucuta              'Duvan',
# 35              Arturo  29.0            Yucatan             'Arturo',
# 36             Jhonner  24.0           Medellín            'Jhonner',
# 39                Axel  27.0       Buenos Aires               'Axel',
# 42             josafat  28.0              CD-MX            'josafat',
# 43                Ivan  27.0               CDMX               'Ivan',
# 44           Alejandro  28.0            Caracas          'Alejandro',
# 48              Arturo  24.0          Maracaibo             'Arturo',
# 54               Marco  22.0               Lima              'Marco',
# 57         Juan Manuel  27.0               CDMX        'Juan Manuel',
# 59    Emilio Alejandro  22.0             Puebla   'Emilio Alejandro',
# 64               Chris  27.0          Los Cabos              'Chris',
# 65            Fernanda  22.0               Lima           'Fernanda',
# 66            Federico  27.0           Medellín           'Federico',
# 68               Mateo  24.0             Bogotá              'Mateo',
# 69              Alexis  27.0           Salvador             'Alexis',
# 72              Andres  28.0             Bogotá             'Andres',
# 78       Camilo Osorio  28.0           Santiago      'Camilo Osorio',
# 81   Fernando Arellano  27.0               CDMX  'Fernando Arellano',
# 85                Luis  26.0  Ciudad de México                'Luis',
# 87             armando  25.0        Cuernavaca             'armando',
# 97      Paquita Cabeza  27.0            Arizona     'Paquita Cabeza',
# 98        Pancho Lopez  28.0              Paris       'Pancho Lopez',
# 104              Naomi  25.0               CDMX              'Naomi',
# 109               Alex  21.0          Monterrey               'Alex',
# 110           Eleonora  22.0             Berlin           'Eleonora',
# 111            Micaela  23.0           Santa Fe                   NaN
#
#     formato_edad        formato_ciudad
# 2          '26',               'CDMX',
# 4          '27',           'Trujillo',
# 6          '25',        'Guadalajara',
# 7          '29',        'Guadalajara',
# 8          '29',         'Cuernavaca',
# 10         '24',                 '24',
# 12         '21',           'La Plata',
# 13         '27',            'Tijuana',
# 14         '25',               'CDMX',
# 15         '25',       'Buenos Aires',
# 16         '26',         'Los patios',
# 18         '26',               'CDMX',
# 20         '28',               'CDMX',
# 23         '27',            'Córdoba',
# 32         '23',          'Monterrey',
# 34         '26',             'Cucuta',
# 35         '29',            'Yucatan',
# 36         '24',           'Medellín',
# 39         '27',       'Buenos Aires',
# 42         '28',              'CD-MX',
# 43         '27',               'CDMX',
# 44         '28',            'Caracas',
# 48         '24',          'Maracaibo',
# 54         '22',               'Lima',
# 57         '27',               'CDMX',
# 59         '22',             'Puebla',
# 64         '27',          'Los Cabos',
# 65         '22',               'Lima',
# 66         '27',           'Medellín',
# 68         '24',             'Bogotá',
# 69         '27',           'Salvador',
# 72         '28',             'Bogotá',
# 78         '28',           'Santiago',
# 81         '27',               'CDMX',
# 85         '26',  'Ciudad de México ',
# 87         '25',        'Cuernavaca ',
# 97         '27',            'Arizona',
# 98         '28',              'Paris',
# 104        '25',               'CDMX',
# 109        '21',          'Monterrey',
# 110        '22',             'Berlin',
# 111          NaN                   NaN

# %%
fila = 110
df.loc[fila, 'Edad']  # Retorna el valor en la fila y columna especificada
# Out:
# 22.0

# %%
df.loc[df["Edad"] == 22, ['Edad', 'Ciudad']]  # Filtrar filas con condición y seleccionar columnas
# Out:
#      Edad  Ciudad
# 54   22.0    Lima
# 59   22.0  Puebla
# 65   22.0    Lima
# 110  22.0  Berlin

# %%
fila_idx = 1
col_idx = 2
df.iloc[fila_idx, col_idx]  # Retorna el valor en la posición de fila y columna índices
# Out:
# 'Comodoro Rivadavia'

# %% [markdown]
# Agrupación y agregación:

# %%
print(df.groupby('Ciudad'))  # Agrupación por ciudad y cálculo de la media de edad
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x78b6c2daf2b0>

# %%
df2.groupby("Edad").count()
# Out:
#         Nombre  Ciudad  formato_name  formato_edad  formato_ciudad
# Edad
# 15.0         1       1             1             1               1
# 20.0         1       1             1             1               1
# 21.0         2       2             2             2               2
# 22.0         4       4             4             4               4
# 23.0         2       2             1             1               1
# 24.0         4       4             4             4               4
# 25.0         5       5             5             5               5
# 26.0         5       5             5             5               5
# 27.0        11      11            11            11              11
# 28.0         6       6             6             6               6
# 29.0         5       5             5             5               5
# 30.0         4       4             4             4               4
# 31.0         2       2             2             2               2
# 32.0         2       2             2             2               2
# 33.0         3       3             3             3               3
# 34.0         1       1             1             1               1
# 35.0         3       3             3             3               3
# 36.0         2       2             2             2               2
# 38.0         1       1             1             1               1
# 39.0         3       3             3             3               3
# 40.0         3       3             2             2               2
# 44.0         3       3             3             3               3
# 45.0         1       1             1             1               1
# 47.0         1       1             1             1               1
# 48.0         1       1             1             1               1
# 50.0         2       2             2             2               2
# 52.0         1       1             1             1               1
# 53.0         2       2             2             2               2
# 57.0         1       1             1             1               1
# 68.0         1       1             1             1               1
# 145.0        2       2             2             2               2
# 500.0        1       1             1             1               1
# 1000.0       1       1             0             0               0

# %%
#df.groupby('Edad').sum()  # Suma de grupos
#df2.groupby('Edad').mean()  # Media de grupos
#df.groupby('Ciudad').agg({'Edad': 'sum'})  # Agregaciones múltiples

# %% [markdown]
# # 6. Fusión y Unión de Datos

# %% [markdown]
# ***¿Conoces los conceptos merge y join? ¿sabes cuál es la diferencia?*** ⁉ ✋

# %% [markdown]
# Uso de merge & join:

# %% [markdown]
# **Merge:**
# El método merge es más flexible y potente para combinar DataFrames o Series. Es muy similar a las operaciones de unión en bases de datos SQL.
#
# `pd.merge(left, right, on='key', how='join_type')`
#
#
# Características:
#
# * on: Especifica la columna o columnas que deben coincidir en ambos DataFrames. Si no se especifica, Pandas intentará unir las tablas basándose en las columnas que tengan nombres en común.
# * how: Define el tipo de unión: 'left', 'right', 'outer', 'inner'. Estos determinan qué registros se incluyen en el DataFrame resultante.
# * Puede unir DataFrames basándose en índices o en una combinación de índices y columnas.
# * Permite especificar múltiples claves de unión mediante una lista en el argumento on.

# %%
df1 = pd.DataFrame({'key': ['A', 'B', 'C'], 'value': [1, 2, 3]})
df1
# Out:
#   key  value
# 0   A      1
# 1   B      2
# 2   C      3

# %%
df2 = pd.DataFrame({'key': ['A', 'B', 'D'], 'value': [4, 5, 6]})
df2
# Out:
#   key  value
# 0   A      4
# 1   B      5
# 2   D      6

# %%
merged_df = pd.merge(df1, df2, on='key', how='inner')
print(merged_df)
# Out:
#   key  value_x  value_y
# 0   A        1        4
# 1   B        2        5

# %% [markdown]
# **Join:**
#
# El método join es una forma más conveniente y menos flexible de combinar DataFrames, ideal para unir DataFrames basándose en sus índices o en una clave de unión en particular.
#
# `df1.join(df2, on='key', how='join_type')`
#
# Características:
#
# * Se utiliza principalmente para unir DataFrames basándose en índices o en una columna de unión específica (usando el argumento on).
# * El argumento how también acepta 'left', 'right', 'outer', 'inner', similar a merge.
# * Por defecto, join realiza una unión izquierda (left join) y está basado en índices.
# * Menos flexible en términos de las claves de unión en comparación con merge, ya que join solo permite especificar una sola clave.

# %%
df1 = pd.DataFrame({'value': [1, 2, 3]}, index=['A', 'B', 'C'])
df2 = pd.DataFrame({'value': [4, 5, 6]}, index=['A', 'B', 'D'])
joined_df = df1.join(df2, lsuffix='_df1', rsuffix='_df2', how='outer')
joined_df2 = df1.join(df2,lsuffix='_df1', rsuffix='_df2', how='inner')
print(joined_df2)
# Out:
#    value_df1  value_df2
# A          1          4
# B          2          5

# %% [markdown]
# # 7. Visualización de Datos con Pandas

# %%
df
# Out:
#         Nombre  Edad              Ciudad  formato_name formato_edad  \
# 0         Joel  40.0                CDMX           NaN          NaN
# 1      Marcela  53.0  Comodoro Rivadavia      Marcela'          53'
# 2       Andrea  26.0                CDMX     'Andrea',        '26',
# 3    Monserrat  33.0         Guadalajara  'Monserrat',        '33',
# 4         José  27.0            Trujillo       'José',        '27',
# ..         ...   ...                 ...           ...          ...
# 106      Sofia  35.0               Salta      'Sofia',        '35',
# 107      Jose    NaN                CDMX      'Jose ',   '35 años',
# 109       Alex  21.0           Monterrey       'Alex',        '21',
# 110   Eleonora  22.0              Berlin   'Eleonora',        '22',
# 111    Micaela  23.0            Santa Fe           NaN          NaN
#
#      formato_ciudad
# 0               NaN
# 1               CR'
# 2           'CDMX',
# 3    'Guadalajara',
# 4       'Trujillo',
# ..              ...
# 106        'Salta',
# 107         'CDMX',
# 109    'Monterrey',
# 110       'Berlin',
# 111             NaN
#
# [88 rows x 6 columns]

# %%
df['Edad'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
